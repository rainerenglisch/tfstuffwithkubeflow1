# %%
import sys
from os.path import expanduser
home = expanduser("~")

sys.path.insert(0,home+"/fairing")
print(sys.path)
# Out:
# ['/home/jovyan/fairing', '/opt/conda/lib/python36.zip', '/opt/conda/lib/python3.6', '/opt/conda/lib/python3.6/lib-dynload', '', '/opt/conda/lib/python3.6/site-packages', '/opt/conda/lib/python3.6/site-packages/object_detection-0.1-py3.6.egg', '/opt/conda/lib/python3.6/site-packages/IPython/extensions', '/home/jovyan/.ipython']

# %%
class TFserve(object):

    def __init__(self):
        print("init")
        self.homeDir = os.getcwd() + "/framework"      
        sys.path.append( self.homeDir + "/TF_obj_detection_original/models/research/slim")
        #self.train_input = "ames_dataset/train.csv"
        #self.n_estimators = 50
        #self.learning_rate = 0.1
        self.model_file = "trained_ames_model.dat"
        self.model = None

# %% [raw]
#     def train(self):
#         os.chdir(self.homeDir+"/TF_obj_detection_original/models/research/")
#         %run -i train  --train_dir=./object_detection/training --pipeline_config_path=./object_detection/training/SSD_resnet50.config
#
#         #eval_model(model, test_X, test_y)
#         #save_model(model, self.model_file)
#
#
# def predict(self, X, feature_names):
#         """Predict using the model for given ndarray."""
#         if not self.model:
#             self.model = joblib.load(self.model_file)
#         # Do any preprocessing
#         prediction = self.model.predict(data=X)
#         # Do any postprocessing
#         return prediction.tolist()
#         #rainer end

# %%
class HousingServe(object):
    
    def __init__(self):

        self.train_input = "ames_dataset/train.csv"
        self.n_estimators = 50
        self.learning_rate = 0.1
        self.model_file = "trained_ames_model.dat"
        self.model = None
        

    def train(self):
        (train_X, train_y), (test_X, test_y) = read_input(self.train_input)
        model = train_model(train_X,
                          train_y,
                          test_X,
                          test_y,
                          self.n_estimators,
                          self.learning_rate)

        eval_model(model, test_X, test_y)
        save_model(model, self.model_file)

    def predict(self, X, feature_names):
        """Predict using the model for given ndarray."""
        if not self.model:
            self.model = joblib.load(self.model_file)
        # Do any preprocessing
        prediction = self.model.predict(data=X)
        # Do any postprocessing
        #rainer start
        #return [[prediction.item(0), prediction.item(0)]]
        return prediction.tolist()
        #rainer end

# %%
tfs = TFserve()
# Out:
# init

# %%
tfs.train()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/4stanislav/tfstuffwithkubeflow1/framework/TF_obj_detection_original/models/research/train.py in <module>
# ----> 1 tfs.train()
#
# ~/4stanislav/tfstuffwithkubeflow1/framework/TF_obj_detection_original/models/research/train.py in train(self)
#      13
#      14     def train(self):
# ---> 15         os.chdir(self.homeDir+"/TF_obj_detection_original/models/research/")
#      16         get_ipython().run_line_magic('run', '-i train  --train_dir=./object_detection/training --pipeline_config_path=./object_detection/training/SSD_resnet50.config')
#      17
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/jovyan/4stanislav/tfstuffwithkubeflow1/framework/TF_obj_detection_original/models/research/framework/TF_obj_detection_original/models/research/'

# %%
import os
import fairing

# Setting up google container repositories (GCR) for storing output containers
# You can use any docker container registry istead of GCR
#GCP_PROJECT = fairing.cloud.gcp.guess_project_name()
#DOCKER_REGISTRY = 'mtr.external.otc.telekomcloud.com/rainer_englisch/kubeflow_test1'
DOCKER_REGISTRY = 'index.docker.io/m1st3rb3an'
PY_VERSION = ".".join([str(x) for x in sys.version_info[0:3]])
BASE_IMAGE = 'library/python:{}'.format(PY_VERSION)
BASE_IMAGE = 'm1st3rb3an/rainers-python:latest'

# %%
from fairing import TrainJob
#from fairing.backends import KubeflowGKEBackend
from fairing.backends import KubeflowBackend
train_job = TrainJob(TFserve, BASE_IMAGE,# input_files=['ames_dataset/train.csv', "requirements.txt"],
                     docker_registry=DOCKER_REGISTRY, backend=KubeflowBackend())
train_job.submit()
# Out:
# ---------------------------------------------------------------------------
# PicklingError                             Traceback (most recent call last)
# ~/4stanislav/tfstuffwithkubeflow1/framework/TF_obj_detection_original/models/research/train.py in <module>
#       3 from fairing.backends import KubeflowBackend
#       4 train_job = TrainJob(TFserve, BASE_IMAGE,# input_files=['ames_dataset/train.csv', "requirements.txt"],
# ----> 5                      docker_registry=DOCKER_REGISTRY, backend=KubeflowBackend())
#       6 train_job.submit()
#
# ~/fairing/fairing/ml_tasks/tasks.py in __init__(self, entry_point, base_docker_image, docker_registry, input_files, backend)
#      55
#      56     def __init__(self, entry_point, base_docker_image, docker_registry, input_files=None, backend=None):
# ---> 57         super().__init__(entry_point, base_docker_image, docker_registry, input_files, backend)
#      58
#      59     def submit(self):
#
# ~/fairing/fairing/ml_tasks/tasks.py in __init__(self, entry_point, base_docker_image, docker_registry, input_files, backend)
#      28         self._backend = backend or KubernetesBackend()
#      29         input_files = input_files or []
# ---> 30         preprocessor = guess_preprocessor(entry_point, input_files=input_files)
#      31         logger.warn("Using preprocessor: {}".format(type(preprocessor)))
#      32
#
# ~/fairing/fairing/ml_tasks/utils.py in guess_preprocessor(entry_point, *args, **kwargs)
#       9 def guess_preprocessor(entry_point, *args, **kwargs):
#      10     if get_execution_obj_type(entry_point) != ObjectType.NOT_SUPPORTED:
# ---> 11         return FunctionPreProcessor(entry_point, *args, **kwargs)
#      12     else:
#      13         # TODO (karthikv2k) Handle other entrypoints like python files and full notebooks
#
# ~/fairing/fairing/preprocessors/function.py in __init__(self, function_obj, path_prefix, output_map, input_files)
#      61         _, temp_payload_file = tempfile.mkstemp()
#      62         with open(temp_payload_file, "wb") as f:
# ---> 63             cloudpickle.dump(function_obj, f)
#      64         # Adding the serialized file to the context
#      65         payload_file_in_context = os.path.join(path_prefix, SERIALIZED_FN_FILE)
#
# /opt/conda/lib/python3.6/site-packages/cloudpickle/cloudpickle.py in dump(obj, file, protocol)
#     934     compatibility with older versions of Python.
#     935     """
# --> 936     CloudPickler(file, protocol=protocol).dump(obj)
#     937
#     938
#
# /opt/conda/lib/python3.6/site-packages/cloudpickle/cloudpickle.py in dump(self, obj)
#     265         self.inject_addons()
#     266         try:
# --> 267             return Pickler.dump(self, obj)
#     268         except RuntimeError as e:
#     269             if 'recursion' in e.args[0]:
#
# /opt/conda/lib/python3.6/pickle.py in dump(self, obj)
#     407         if self.proto >= 4:
#     408             self.framer.start_framing()
# --> 409         self.save(obj)
#     410         self.write(STOP)
#     411         self.framer.end_framing()
#
# /opt/conda/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# /opt/conda/lib/python3.6/site-packages/cloudpickle/cloudpickle.py in save_global(self, obj, name, pack)
#     691
#     692         if obj.__module__ == "__main__":
# --> 693             return self.save_dynamic_class(obj)
#     694
#     695         try:
#
# /opt/conda/lib/python3.6/site-packages/cloudpickle/cloudpickle.py in save_dynamic_class(self, obj)
#     530         # Now save the rest of obj's __dict__. Any references to obj
#     531         # encountered while saving will point to the skeleton class.
# --> 532         save(clsdict)
#     533
#     534         # Write a tuple of (skeleton_class, clsdict).
#
# /opt/conda/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# /opt/conda/lib/python3.6/pickle.py in save_dict(self, obj)
#     819
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#     823     dispatch[dict] = save_dict
#
# /opt/conda/lib/python3.6/pickle.py in _batch_setitems(self, items)
#     845                 for k, v in tmp:
#     846                     save(k)
# --> 847                     save(v)
#     848                 write(SETITEMS)
#     849             elif n:
#
# /opt/conda/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# /opt/conda/lib/python3.6/site-packages/cloudpickle/cloudpickle.py in save_function(self, obj, name)
#     393                 or getattr(obj.__code__, 'co_filename', None) == '<stdin>'
#     394                 or themodule is None):
# --> 395             self.save_function_tuple(obj)
#     396             return
#     397         else:
#
# /opt/conda/lib/python3.6/site-packages/cloudpickle/cloudpickle.py in save_function_tuple(self, func)
#     592         if hasattr(func, '__qualname__'):
#     593             state['qualname'] = func.__qualname__
# --> 594         save(state)
#     595         write(pickle.TUPLE)
#     596         write(pickle.REDUCE)  # applies _fill_function on the tuple
#
# /opt/conda/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# /opt/conda/lib/python3.6/pickle.py in save_dict(self, obj)
#     819
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#     823     dispatch[dict] = save_dict
#
# /opt/conda/lib/python3.6/pickle.py in _batch_setitems(self, items)
#     845                 for k, v in tmp:
#     846                     save(k)
# --> 847                     save(v)
#     848                 write(SETITEMS)
#     849             elif n:
#
# /opt/conda/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# /opt/conda/lib/python3.6/pickle.py in save_dict(self, obj)
#     819
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#     823     dispatch[dict] = save_dict
#
# /opt/conda/lib/python3.6/pickle.py in _batch_setitems(self, items)
#     845                 for k, v in tmp:
#     846                     save(k)
# --> 847                     save(v)
#     848                 write(SETITEMS)
#     849             elif n:
#
# /opt/conda/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# /opt/conda/lib/python3.6/site-packages/cloudpickle/cloudpickle.py in save_instancemethod(self, obj)
#     716         else:
#     717             if PY3:  # pragma: no branch
# --> 718                 self.save_reduce(types.MethodType, (obj.__func__, obj.__self__), obj=obj)
#     719             else:
#     720                 self.save_reduce(types.MethodType, (obj.__func__, obj.__self__, obj.__self__.__class__),
#
# /opt/conda/lib/python3.6/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     608         else:
#     609             save(func)
# --> 610             save(args)
#     611             write(REDUCE)
#     612
#
# /opt/conda/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# /opt/conda/lib/python3.6/pickle.py in save_tuple(self, obj)
#     734         if n <= 3 and self.proto >= 2:
#     735             for element in obj:
# --> 736                 save(element)
#     737             # Subtle.  Same as in the big comment below.
#     738             if id(obj) in memo:
#
# /opt/conda/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     519
#     520         # Save the reduce() output and finally memoize the object
# --> 521         self.save_reduce(obj=obj, *rv)
#     522
#     523     def persistent_id(self, obj):
#
# /opt/conda/lib/python3.6/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     632
#     633         if state is not None:
# --> 634             save(state)
#     635             write(BUILD)
#     636
#
# /opt/conda/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# /opt/conda/lib/python3.6/pickle.py in save_dict(self, obj)
#     819
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#     823     dispatch[dict] = save_dict
#
# /opt/conda/lib/python3.6/pickle.py in _batch_setitems(self, items)
#     845                 for k, v in tmp:
#     846                     save(k)
# --> 847                     save(v)
#     848                 write(SETITEMS)
#     849             elif n:
#
# /opt/conda/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# /opt/conda/lib/python3.6/pickle.py in save_dict(self, obj)
#     819
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#     823     dispatch[dict] = save_dict
#
# /opt/conda/lib/python3.6/pickle.py in _batch_setitems(self, items)
#     845                 for k, v in tmp:
#     846                     save(k)
# --> 847                     save(v)
#     848                 write(SETITEMS)
#     849             elif n:
#
# /opt/conda/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     519
#     520         # Save the reduce() output and finally memoize the object
# --> 521         self.save_reduce(obj=obj, *rv)
#     522
#     523     def persistent_id(self, obj):
#
# /opt/conda/lib/python3.6/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     632
#     633         if state is not None:
# --> 634             save(state)
#     635             write(BUILD)
#     636
#
# /opt/conda/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# /opt/conda/lib/python3.6/pickle.py in save_dict(self, obj)
#     819
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#     823     dispatch[dict] = save_dict
#
# /opt/conda/lib/python3.6/pickle.py in _batch_setitems(self, items)
#     845                 for k, v in tmp:
#     846                     save(k)
# --> 847                     save(v)
#     848                 write(SETITEMS)
#     849             elif n:
#
# /opt/conda/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# /opt/conda/lib/python3.6/pickle.py in save_dict(self, obj)
#     819
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#     823     dispatch[dict] = save_dict
#
# /opt/conda/lib/python3.6/pickle.py in _batch_setitems(self, items)
#     845                 for k, v in tmp:
#     846                     save(k)
# --> 847                     save(v)
#     848                 write(SETITEMS)
#     849             elif n:
#
# /opt/conda/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# /opt/conda/lib/python3.6/site-packages/cloudpickle/cloudpickle.py in save_builtin_function(self, obj)
#     672         if obj.__module__ == "__builtin__":
#     673             return self.save_global(obj)
# --> 674         return self.save_function(obj)
#     675
#     676     dispatch[types.BuiltinFunctionType] = save_builtin_function
#
# /opt/conda/lib/python3.6/site-packages/cloudpickle/cloudpickle.py in save_function(self, obj, name)
#     385                 else:
#     386                     raise pickle.PicklingError("Can't pickle %r" % obj)
# --> 387             return self.save_reduce(obj=obj, *rv)
#     388
#     389         # if func is lambda, def'ed at prompt, is in main, or is nested, then
#
# /opt/conda/lib/python3.6/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     542
#     543         if not isinstance(args, tuple):
# --> 544             raise PicklingError("args from save_reduce() must be a tuple")
#     545         if not callable(func):
#     546             raise PicklingError("func from save_reduce() must be callable")
#
# PicklingError: args from save_reduce() must be a tuple
